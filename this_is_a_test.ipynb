# %%
import numpy as np
import pandas as pd
import matplotlib as pyplot
import tensorflow 
from tensorflow import keras

# %%
# Defining the model architecture
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

# Compile the model with a loss function, optimizer, and evaluation metrics
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
import requests
from bs4 import BeautifulSoup

# Define the URL and headers
url = "https://finance.yahoo.com/quote/BTC-USD/history?p=BTC-USD"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36"
}

# Send a GET request to the URL with the headers
response = requests.get(url, headers=headers)

# Create a BeautifulSoup object to parse the HTML content
soup = BeautifulSoup(response.text, "html.parser")

# Find the historical data table
table = soup.find("table", {"data-test": "historical-prices"})

# Extract the table headers and rows
headers = [th.text for th in table.find_all("th")]
rows = []
for tr in table.find_all("tr")[1:]:
    row = [td.text for td in tr.find_all("td")]
    rows.append(row)

# Print the table headers and rows
print(headers)
print(rows)
# Out:
# ['Date', 'Open', 'High', 'Low', 'Close*', 'Adj Close**', 'Volume']
# [['Feb 27, 2023', '23,551.75', '23,757.73', '23,356.67', '23,733.63', '23,733.63', '19,089,268,736'], ['Feb 26, 2023', '23,174.15', '23,654.37', '23,084.22', '23,561.21', '23,561.21', '16,644,534,842'], ['Feb 25, 2023', '23,200.13', '23,210.21', '22,861.56', '23,175.38', '23,175.38', '16,100,721,565'], ['Feb 24, 2023', '23,946.01', '24,103.71', '23,007.07', '23,198.13', '23,198.13', '26,811,744,928'], ['Feb 23, 2023', '24,190.72', '24,572.09', '23,693.92', '23,947.49', '23,947.49', '30,476,264,066'], ['Feb 22, 2023', '24,437.42', '24,472.34', '23,644.32', '24,188.84', '24,188.84', '30,199,996,781'], ['Feb 21, 2023', '24,833.05', '25,126.85', '24,200.36', '24,436.35', '24,436.35', '31,252,098,714'], ['Feb 20, 2023', '24,336.62', '25,020.46', '23,927.91', '24,829.15', '24,829.15', '28,987,376,573'], ['Feb 19, 2023', '24,640.03', '25,093.05', '24,327.64', '24,327.64', '24,327.64', '25,555,105,670'], ['Feb 18, 2023', '24,565.30', '24,798.84', '24,468.37', '24,641.28', '24,641.28', '19,625,427,158'], ['Feb 17, 2023', '23,621.28', '24,924.04', '23,460.76', '24,565.60', '24,565.60', '41,358,451,255'], ['Feb 16, 2023', '24,307.35', '25,134.12', '23,602.52', '23,623.47', '23,623.47', '39,316,664,596'], ['Feb 15, 2023', '22,220.59', '24,307.84', '22,082.77', '24,307.84', '24,307.84', '32,483,312,909'], ['Feb 14, 2023', '21,801.82', '22,293.14', '21,632.39', '22,220.80', '22,220.80', '26,792,596,581'], ['Feb 13, 2023', '21,787.00', '21,898.41', '21,460.09', '21,808.10', '21,808.10', '23,918,742,607'], ['Feb 12, 2023', '21,870.90', '22,060.99', '21,682.83', '21,788.20', '21,788.20', '17,821,046,406'],